# %%
# 3 strategies for financial markets to make money in the stock markets
# Conflict of interest - not efficient for retail traders
# What automation has taken place in financial markets
# recommended book - Advances in Financial Machine Learning by 
# Marcos Lopez De Prado
# the next big thing is = ALPHA
# Excess returns of an investment relative to a benchmark. 
# (for example S&P500 index)

# %%
# The 3 strategies that are proved profitable
# first we start with the basics

# %% [markdown]
# ## Market Participants
# ### Directional
# * Assets Managers
# * INvestment Banks
# * Pension Funds
# * Mutual Funds
# * Retail Investors
# * Others
# ### Non-Directional
# * Market Markers
# * Brokers
# * Intermediaries
# * Internalisers
# * High-Frequency Traders
# * Others
#
# ### 1. Strategy 1: Fees for Financial Services
# ### 2. Market Making Bid-Ask Spread
# ### 3. Brokerage or Commission Fees

# %%
import yfinance as yf
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
apple = yf.download('AAPL',start='2010-01-01', end='2021-01-01')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
apple
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-01-04    7.622500    7.660714    7.585000    7.643214    6.470742
# 2010-01-05    7.664286    7.699643    7.616071    7.656429    6.481929
# 2010-01-06    7.656429    7.686786    7.526786    7.534643    6.378825
# 2010-01-07    7.562500    7.571429    7.466071    7.520714    6.367033
# 2010-01-08    7.510714    7.571429    7.466429    7.570714    6.409362
# ...                ...         ...         ...         ...         ...
# 2020-12-24  131.320007  133.460007  131.100006  131.970001  129.514465
# 2020-12-28  133.990005  137.339996  133.509995  136.690002  134.146667
# 2020-12-29  138.050003  138.789993  134.339996  134.869995  132.360504
# 2020-12-30  135.580002  135.990005  133.399994  133.720001  131.231918
# 2020-12-31  134.080002  134.740005  131.720001  132.690002  130.221115
#
#                Volume
# Date
# 2010-01-04  493729600
# 2010-01-05  601904800
# 2010-01-06  552160000
# ...

# %%
ticker = ["SPY",'AAPL','KO']

# %%
stocks = yf.download(ticker, start = '2010-01-01', end='2021-01-01')
# Out:
# [*********************100%%**********************]  3 of 3 completed

# %%
stocks
# Out:
#              Adj Close                              Close             \
#                   AAPL         KO         SPY        AAPL         KO
# Date
# 2010-01-04    6.470742  18.351225   86.860069    7.643214  28.520000
# 2010-01-05    6.481929  18.129234   87.090019    7.656429  28.174999
# 2010-01-06    6.378825  18.122808   87.151321    7.534643  28.165001
# 2010-01-07    6.367033  18.077766   87.519196    7.520714  28.094999
# 2010-01-08    6.409362  17.743174   87.810455    7.570714  27.575001
# ...                ...        ...         ...         ...        ...
# 2020-12-24  129.514465  48.392033  351.874756  131.970001  53.439999
# 2020-12-28  134.146667  49.044022  354.897675  136.690002  54.160000
# 2020-12-29  132.360504  49.016861  354.220520  134.869995  54.130001
# 2020-12-30  131.231918  49.297577  354.725952  133.720001  54.439999
# 2020-12-31  130.221115  49.659794  356.528259  132.690002  54.840000
#
# ...

# %%
# date format 'yyyy-mm-dd'

# %%
stocks.head()
# Out:
#            Adj Close                           Close                         \
#                 AAPL         KO        SPY      AAPL         KO         SPY
# Date
# 2010-01-04  6.470742  18.351225  86.860069  7.643214  28.520000  113.330002
# 2010-01-05  6.481929  18.129234  87.090019  7.656429  28.174999  113.629997
# 2010-01-06  6.378825  18.122808  87.151321  7.534643  28.165001  113.709999
# 2010-01-07  6.367033  18.077766  87.519196  7.520714  28.094999  114.190002
# 2010-01-08  6.409362  17.743174  87.810455  7.570714  27.575001  114.570000
#
#                 High                              Low                         \
#                 AAPL         KO         SPY      AAPL         KO         SPY
# Date
# 2010-01-04  7.660714  28.610001  113.389999  7.585000  28.450001  111.510002
# 2010-01-05  7.699643  28.495001  113.680000  7.616071  28.070000  112.849998
# 2010-01-06  7.686786  28.219999  113.989998  7.526786  27.990000  113.430000
# ...

# %%
stocks.tail()
# Out:
#              Adj Close                              Close             \
#                   AAPL         KO         SPY        AAPL         KO
# Date
# 2020-12-24  129.514465  48.392033  351.874756  131.970001  53.439999
# 2020-12-28  134.146667  49.044022  354.897675  136.690002  54.160000
# 2020-12-29  132.360504  49.016861  354.220520  134.869995  54.130001
# 2020-12-30  131.231918  49.297577  354.725952  133.720001  54.439999
# 2020-12-31  130.221115  49.659794  356.528259  132.690002  54.840000
#
#                               High                                Low  \
#                    SPY        AAPL         KO         SPY        AAPL
# Date
# 2020-12-24  369.000000  133.460007  53.549999  369.029999  131.100006
# 2020-12-28  372.170013  137.339996  54.439999  372.589996  133.509995
# 2020-12-29  371.459991  138.789993  54.490002  374.000000  134.339996
# 2020-12-30  371.989990  135.990005  54.630001  373.100006  133.399994
# ...

# %%
stocks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2769 entries, 2010-01-04 to 2020-12-31
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   (Adj Close, AAPL)  2769 non-null   float64
#  1   (Adj Close, KO)    2769 non-null   float64
#  2   (Adj Close, SPY)   2769 non-null   float64
#  3   (Close, AAPL)      2769 non-null   float64
#  4   (Close, KO)        2769 non-null   float64
#  5   (Close, SPY)       2769 non-null   float64
#  6   (High, AAPL)       2769 non-null   float64
#  7   (High, KO)         2769 non-null   float64
#  8   (High, SPY)        2769 non-null   float64
#  9   (Low, AAPL)        2769 non-null   float64
#  10  (Low, KO)          2769 non-null   float64
#  11  (Low, SPY)         2769 non-null   float64
#  12  (Open, AAPL)       2769 non-null   float64
#  13  (Open, KO)         2769 non-null   float64
#  14  (Open, SPY)        2769 non-null   float64
# ...

# %%
stocks.to_csv('stocks_data.csv')

# %%
stocks = pd.read_csv('stocks_data.csv', header=[0,1])
stocks
# Out:
#      Unnamed: 0_level_0   Adj Close                              Close  \
#      Unnamed: 0_level_1        AAPL         KO         SPY        AAPL
# 0                  Date         NaN        NaN         NaN         NaN
# 1            2010-01-04    6.470742  18.351225   86.860069    7.643214
# 2            2010-01-05    6.481929  18.129234   87.090019    7.656429
# 3            2010-01-06    6.378825  18.122808   87.151321    7.534643
# 4            2010-01-07    6.367033  18.077766   87.519196    7.520714
# ...                 ...         ...        ...         ...         ...
# 2765         2020-12-24  129.514465  48.392033  351.874756  131.970001
# 2766         2020-12-28  134.146667  49.044022  354.897675  136.690002
# 2767         2020-12-29  132.360504  49.016861  354.220520  134.869995
# 2768         2020-12-30  131.231918  49.297577  354.725952  133.720001
# 2769         2020-12-31  130.221115  49.659794  356.528259  132.690002
#
# ...

# %%
stocks = pd.read_csv('stocks_data.csv', header=[0,1], index_col=[0])
stocks
# Out:
#              Adj Close                              Close             \
#                   AAPL         KO         SPY        AAPL         KO
# Date
# 2010-01-04    6.470742  18.351225   86.860069    7.643214  28.520000
# 2010-01-05    6.481929  18.129234   87.090019    7.656429  28.174999
# 2010-01-06    6.378825  18.122808   87.151321    7.534643  28.165001
# 2010-01-07    6.367033  18.077766   87.519196    7.520714  28.094999
# 2010-01-08    6.409362  17.743174   87.810455    7.570714  27.575001
# ...                ...        ...         ...         ...        ...
# 2020-12-24  129.514465  48.392033  351.874756  131.970001  53.439999
# 2020-12-28  134.146667  49.044022  354.897675  136.690002  54.160000
# 2020-12-29  132.360504  49.016861  354.220520  134.869995  54.130001
# 2020-12-30  131.231918  49.297577  354.725952  133.720001  54.439999
# 2020-12-31  130.221115  49.659794  356.528259  132.690002  54.840000
#
# ...

# %%
stocks = pd.read_csv('stocks_data.csv', header=[0,1], index_col =[0], parse_dates=[0])
stocks
# Out:
#              Adj Close                              Close             \
#                   AAPL         KO         SPY        AAPL         KO
# Date
# 2010-01-04    6.470742  18.351225   86.860069    7.643214  28.520000
# 2010-01-05    6.481929  18.129234   87.090019    7.656429  28.174999
# 2010-01-06    6.378825  18.122808   87.151321    7.534643  28.165001
# 2010-01-07    6.367033  18.077766   87.519196    7.520714  28.094999
# 2010-01-08    6.409362  17.743174   87.810455    7.570714  27.575001
# ...                ...        ...         ...         ...        ...
# 2020-12-24  129.514465  48.392033  351.874756  131.970001  53.439999
# 2020-12-28  134.146667  49.044022  354.897675  136.690002  54.160000
# 2020-12-29  132.360504  49.016861  354.220520  134.869995  54.130001
# 2020-12-30  131.231918  49.297577  354.725952  133.720001  54.439999
# 2020-12-31  130.221115  49.659794  356.528259  132.690002  54.840000
#
# ...

# %%
stocks.columns
# Out:
# MultiIndex([('Adj Close', 'AAPL'),
#             ('Adj Close',   'KO'),
#             ('Adj Close',  'SPY'),
#             (    'Close', 'AAPL'),
#             (    'Close',   'KO'),
#             (    'Close',  'SPY'),
#             (     'High', 'AAPL'),
#             (     'High',   'KO'),
#             (     'High',  'SPY'),
#             (      'Low', 'AAPL'),
#             (      'Low',   'KO'),
#             (      'Low',  'SPY'),
#             (     'Open', 'AAPL'),
#             (     'Open',   'KO'),
#             (     'Open',  'SPY'),
#             (   'Volume', 'AAPL'),
#             (   'Volume',   'KO'),
#             (   'Volume',  'SPY')],
#            )

# %%
# convert multi-index to one tuple...
stocks.columns = stocks.columns.to_flat_index()

# %%
stocks.columns
# Out:
# Index([('Adj Close', 'AAPL'),   ('Adj Close', 'KO'),  ('Adj Close', 'SPY'),
#            ('Close', 'AAPL'),       ('Close', 'KO'),      ('Close', 'SPY'),
#             ('High', 'AAPL'),        ('High', 'KO'),       ('High', 'SPY'),
#              ('Low', 'AAPL'),         ('Low', 'KO'),        ('Low', 'SPY'),
#             ('Open', 'AAPL'),        ('Open', 'KO'),       ('Open', 'SPY'),
#           ('Volume', 'AAPL'),      ('Volume', 'KO'),     ('Volume', 'SPY')],
#       dtype='object')

# %%
stocks
# Out:
#             (Adj Close, AAPL)  (Adj Close, KO)  (Adj Close, SPY)  \
# Date
# 2010-01-04           6.470742        18.351225         86.860069
# 2010-01-05           6.481929        18.129234         87.090019
# 2010-01-06           6.378825        18.122808         87.151321
# 2010-01-07           6.367033        18.077766         87.519196
# 2010-01-08           6.409362        17.743174         87.810455
# ...                       ...              ...               ...
# 2020-12-24         129.514465        48.392033        351.874756
# 2020-12-28         134.146667        49.044022        354.897675
# 2020-12-29         132.360504        49.016861        354.220520
# 2020-12-30         131.231918        49.297577        354.725952
# 2020-12-31         130.221115        49.659794        356.528259
#
#             (Close, AAPL)  (Close, KO)  (Close, SPY)  (High, AAPL)  \
# Date
# 2010-01-04       7.643214    28.520000    113.330002      7.660714
# ...

# %%
stocks.T
# Out:
# Date                 2010-01-04    2010-01-05    2010-01-06    2010-01-07  \
# (Adj Close, AAPL)  6.470742e+00  6.481929e+00  6.378825e+00  6.367033e+00
# (Adj Close, KO)    1.835122e+01  1.812923e+01  1.812281e+01  1.807777e+01
# (Adj Close, SPY)   8.686007e+01  8.709002e+01  8.715132e+01  8.751920e+01
# (Close, AAPL)      7.643214e+00  7.656429e+00  7.534643e+00  7.520714e+00
# (Close, KO)        2.852000e+01  2.817500e+01  2.816500e+01  2.809500e+01
# (Close, SPY)       1.133300e+02  1.136300e+02  1.137100e+02  1.141900e+02
# (High, AAPL)       7.660714e+00  7.699643e+00  7.686786e+00  7.571429e+00
# (High, KO)         2.861000e+01  2.849500e+01  2.822000e+01  2.818500e+01
# (High, SPY)        1.133900e+02  1.136800e+02  1.139900e+02  1.143300e+02
# (Low, AAPL)        7.585000e+00  7.616071e+00  7.526786e+00  7.466071e+00
# (Low, KO)          2.845000e+01  2.807000e+01  2.799000e+01  2.787500e+01
# (Low, SPY)         1.115100e+02  1.128500e+02  1.134300e+02  1.131800e+02
# ...

# %%
stocks.columns = pd.MultiIndex.from_tuples(stocks.columns)
stocks
# Out:
#              Adj Close                              Close             \
#                   AAPL         KO         SPY        AAPL         KO
# Date
# 2010-01-04    6.470742  18.351225   86.860069    7.643214  28.520000
# 2010-01-05    6.481929  18.129234   87.090019    7.656429  28.174999
# 2010-01-06    6.378825  18.122808   87.151321    7.534643  28.165001
# 2010-01-07    6.367033  18.077766   87.519196    7.520714  28.094999
# 2010-01-08    6.409362  17.743174   87.810455    7.570714  27.575001
# ...                ...        ...         ...         ...        ...
# 2020-12-24  129.514465  48.392033  351.874756  131.970001  53.439999
# 2020-12-28  134.146667  49.044022  354.897675  136.690002  54.160000
# 2020-12-29  132.360504  49.016861  354.220520  134.869995  54.130001
# 2020-12-30  131.231918  49.297577  354.725952  133.720001  54.439999
# 2020-12-31  130.221115  49.659794  356.528259  132.690002  54.840000
#
# ...

# %%
stocks.columns
# Out:
# MultiIndex([('Adj Close', 'AAPL'),
#             ('Adj Close',   'KO'),
#             ('Adj Close',  'SPY'),
#             (    'Close', 'AAPL'),
#             (    'Close',   'KO'),
#             (    'Close',  'SPY'),
#             (     'High', 'AAPL'),
#             (     'High',   'KO'),
#             (     'High',  'SPY'),
#             (      'Low', 'AAPL'),
#             (      'Low',   'KO'),
#             (      'Low',  'SPY'),
#             (     'Open', 'AAPL'),
#             (     'Open',   'KO'),
#             (     'Open',  'SPY'),
#             (   'Volume', 'AAPL'),
#             (   'Volume',   'KO'),
#             (   'Volume',  'SPY')],
#            )

# %%
stocks.describe()
# Out:
#          Adj Close                                  Close               \
#               AAPL           KO          SPY         AAPL           KO
# count  2769.000000  2769.000000  2769.000000  2769.000000  2769.000000
# mean     31.522342    31.953174   181.488476    33.777537    41.320121
# std      24.583424     8.118785    69.487674    24.572747     6.808527
# min       5.806767    16.243889    79.026421     6.858929    25.014999
# 25%      15.181943    26.394423   114.525398    17.484285    37.660000
# 50%      24.517962    31.516817   175.435959    26.987499    41.759998
# 75%      40.879478    37.329918   241.183395    43.007500    45.549999
# max     134.146667    52.648430   356.528259   136.690002    60.130001
#
#                            High                                    Low  \
#                SPY         AAPL           KO          SPY         AAPL
# count  2769.000000  2769.000000  2769.000000  2769.000000  2769.000000
# ...

# %% [markdown]
# ### iloc and loc functions

# %%
stocks.loc[:,'Close']
# Out:
#                   AAPL         KO         SPY
# Date
# 2010-01-04    7.643214  28.520000  113.330002
# 2010-01-05    7.656429  28.174999  113.629997
# 2010-01-06    7.534643  28.165001  113.709999
# 2010-01-07    7.520714  28.094999  114.190002
# 2010-01-08    7.570714  27.575001  114.570000
# ...                ...        ...         ...
# 2020-12-24  131.970001  53.439999  369.000000
# 2020-12-28  136.690002  54.160000  372.170013
# 2020-12-29  134.869995  54.130001  371.459991
# 2020-12-30  133.720001  54.439999  371.989990
# 2020-12-31  132.690002  54.840000  373.880005
#
# [2769 rows x 3 columns]

# %%
close = stocks.loc[:, 'Close'].copy()
close
# Out:
#                   AAPL         KO         SPY
# Date
# 2010-01-04    7.643214  28.520000  113.330002
# 2010-01-05    7.656429  28.174999  113.629997
# 2010-01-06    7.534643  28.165001  113.709999
# 2010-01-07    7.520714  28.094999  114.190002
# 2010-01-08    7.570714  27.575001  114.570000
# ...                ...        ...         ...
# 2020-12-24  131.970001  53.439999  369.000000
# 2020-12-28  136.690002  54.160000  372.170013
# 2020-12-29  134.869995  54.130001  371.459991
# 2020-12-30  133.720001  54.439999  371.989990
# 2020-12-31  132.690002  54.840000  373.880005
#
# [2769 rows x 3 columns]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn')
# Out:
# C:\Users\The Geek Dev\AppData\Local\Temp\ipykernel_9652\1843973781.py:3: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %%
close.plot(figsize = (12,5), fontsize = 12)
plt.legend(fontsize = 12)
plt.show()

# %%
close.iloc[0,0]
# Out:
# 7.643214225769043

# %%
close.AAPL
# Out:
# Date
# 2010-01-04      7.643214
# 2010-01-05      7.656429
# 2010-01-06      7.534643
# 2010-01-07      7.520714
# 2010-01-08      7.570714
#                  ...
# 2020-12-24    131.970001
# 2020-12-28    136.690002
# 2020-12-29    134.869995
# 2020-12-30    133.720001
# 2020-12-31    132.690002
# Name: AAPL, Length: 2769, dtype: float64

# %%
close.AAPL.div(close.iloc[0,0])
# Out:
# Date
# 2010-01-04     1.000000
# 2010-01-05     1.001729
# 2010-01-06     0.985795
# 2010-01-07     0.983973
# 2010-01-08     0.990514
#                 ...
# 2020-12-24    17.266296
# 2020-12-28    17.883838
# 2020-12-29    17.645717
# 2020-12-30    17.495258
# 2020-12-31    17.360498
# Name: AAPL, Length: 2769, dtype: float64

# %%
close.AAPL.div(close.iloc[0,0]).mul(100)
# Out:
# Date
# 2010-01-04     100.000000
# 2010-01-05     100.172893
# 2010-01-06      98.579511
# 2010-01-07      98.397266
# 2010-01-08      99.051443
#                  ...
# 2020-12-24    1726.629626
# 2020-12-28    1788.383766
# 2020-12-29    1764.571699
# 2020-12-30    1749.525753
# 2020-12-31    1736.049763
# Name: AAPL, Length: 2769, dtype: float64

# %%
norm_close = close.div(close.iloc[0]).mul(100)

# %%
norm_close
# Out:
#                    AAPL          KO         SPY
# Date
# 2010-01-04   100.000000  100.000000  100.000000
# 2010-01-05   100.172893   98.790318  100.264710
# 2010-01-06    98.579511   98.755261  100.335302
# 2010-01-07    98.397266   98.509814  100.758846
# 2010-01-08    99.051443   96.686537  101.094148
# ...                 ...         ...         ...
# 2020-12-24  1726.629626  187.377271  325.597806
# 2020-12-28  1788.383766  189.901820  328.394959
# 2020-12-29  1764.571699  189.796635  327.768451
# 2020-12-30  1749.525753  190.883583  328.236111
# 2020-12-31  1736.049763  192.286112  329.903820
#
# [2769 rows x 3 columns]

# %%
norm_close.plot(figsize = (12,5), fontsize = 12)
plt.legend(fontsize = 12)
plt.show()

# %%
 # Focusing on the returns of apple only..

# %%
apple = close.AAPL.copy().to_frame()

# %%
apple
# Out:
#                   AAPL
# Date
# 2010-01-04    7.643214
# 2010-01-05    7.656429
# 2010-01-06    7.534643
# 2010-01-07    7.520714
# 2010-01-08    7.570714
# ...                ...
# 2020-12-24  131.970001
# 2020-12-28  136.690002
# 2020-12-29  134.869995
# 2020-12-30  133.720001
# 2020-12-31  132.690002
#
# [2769 rows x 1 columns]

# %%
# calculate the decrease/ increase from the previous day...

# %%
apple.shift(periods=1)
# Out:
#                   AAPL
# Date
# 2010-01-04         NaN
# 2010-01-05    7.643214
# 2010-01-06    7.656429
# 2010-01-07    7.534643
# 2010-01-08    7.520714
# ...                ...
# 2020-12-24  130.960007
# 2020-12-28  131.970001
# 2020-12-29  136.690002
# 2020-12-30  134.869995
# 2020-12-31  133.720001
#
# [2769 rows x 1 columns]

# %%
# create a new column
apple['lag1'] = apple.shift(periods=1)
apple
# Out:
#                   AAPL        lag1
# Date
# 2010-01-04    7.643214         NaN
# 2010-01-05    7.656429    7.643214
# 2010-01-06    7.534643    7.656429
# 2010-01-07    7.520714    7.534643
# 2010-01-08    7.570714    7.520714
# ...                ...         ...
# 2020-12-24  131.970001  130.960007
# 2020-12-28  136.690002  131.970001
# 2020-12-29  134.869995  136.690002
# 2020-12-30  133.720001  134.869995
# 2020-12-31  132.690002  133.720001
#
# [2769 rows x 2 columns]

# %%
apple.AAPL.sub(apple.lag1)
# Out:
# Date
# 2010-01-04         NaN
# 2010-01-05    0.013215
# 2010-01-06   -0.121786
# 2010-01-07   -0.013929
# 2010-01-08    0.050000
#                 ...
# 2020-12-24    1.009995
# 2020-12-28    4.720001
# 2020-12-29   -1.820007
# 2020-12-30   -1.149994
# 2020-12-31   -1.029999
# Length: 2769, dtype: float64

# %%
apple['Diff'] = apple.AAPL.sub(apple.lag1)
apple
# Out:
#                   AAPL        lag1      Diff
# Date
# 2010-01-04    7.643214         NaN       NaN
# 2010-01-05    7.656429    7.643214  0.013215
# 2010-01-06    7.534643    7.656429 -0.121786
# 2010-01-07    7.520714    7.534643 -0.013929
# 2010-01-08    7.570714    7.520714  0.050000
# ...                ...         ...       ...
# 2020-12-24  131.970001  130.960007  1.009995
# 2020-12-28  136.690002  131.970001  4.720001
# 2020-12-29  134.869995  136.690002 -1.820007
# 2020-12-30  133.720001  134.869995 -1.149994
# 2020-12-31  132.690002  133.720001 -1.029999
#
# [2769 rows x 3 columns]

# %%
# calculating the percentage change...

# %%
apple['% change'] = apple.AAPL.div(apple.lag1).sub(1).mul(100)
apple
# Out:
#                   AAPL        lag1      Diff  % change
# Date
# 2010-01-04    7.643214         NaN       NaN       NaN
# 2010-01-05    7.656429    7.643214  0.013215  0.172893
# 2010-01-06    7.534643    7.656429 -0.121786 -1.590632
# 2010-01-07    7.520714    7.534643 -0.013929 -0.184871
# 2010-01-08    7.570714    7.520714  0.050000  0.664833
# ...                ...         ...       ...       ...
# 2020-12-24  131.970001  130.960007  1.009995  0.771224
# 2020-12-28  136.690002  131.970001  4.720001  3.576571
# 2020-12-29  134.869995  136.690002 -1.820007 -1.331485
# 2020-12-30  133.720001  134.869995 -1.149994 -0.852668
# 2020-12-31  132.690002  133.720001 -1.029999 -0.770265
#
# [2769 rows x 4 columns]

# %%
# using the diff method as well
apple['Diff2'] = apple.AAPL.diff(periods=1)
apple
# Out:
#                   AAPL        lag1      Diff  % change     Diff2
# Date
# 2010-01-04    7.643214         NaN       NaN       NaN       NaN
# 2010-01-05    7.656429    7.643214  0.013215  0.172893  0.013215
# 2010-01-06    7.534643    7.656429 -0.121786 -1.590632 -0.121786
# 2010-01-07    7.520714    7.534643 -0.013929 -0.184871 -0.013929
# 2010-01-08    7.570714    7.520714  0.050000  0.664833  0.050000
# ...                ...         ...       ...       ...       ...
# 2020-12-24  131.970001  130.960007  1.009995  0.771224  1.009995
# 2020-12-28  136.690002  131.970001  4.720001  3.576571  4.720001
# 2020-12-29  134.869995  136.690002 -1.820007 -1.331485 -1.820007
# 2020-12-30  133.720001  134.869995 -1.149994 -0.852668 -1.149994
# 2020-12-31  132.690002  133.720001 -1.029999 -0.770265 -1.029999
#
# [2769 rows x 5 columns]

# %%
apple['%change2'] = apple.AAPL.pct_change(periods=1).mul(100)
apple
# Out:
#                   AAPL        lag1      Diff  % change     Diff2  %change2
# Date
# 2010-01-04    7.643214         NaN       NaN       NaN       NaN       NaN
# 2010-01-05    7.656429    7.643214  0.013215  0.172893  0.013215  0.172893
# 2010-01-06    7.534643    7.656429 -0.121786 -1.590632 -0.121786 -1.590632
# 2010-01-07    7.520714    7.534643 -0.013929 -0.184871 -0.013929 -0.184871
# 2010-01-08    7.570714    7.520714  0.050000  0.664833  0.050000  0.664833
# ...                ...         ...       ...       ...       ...       ...
# 2020-12-24  131.970001  130.960007  1.009995  0.771224  1.009995  0.771224
# 2020-12-28  136.690002  131.970001  4.720001  3.576571  4.720001  3.576571
# 2020-12-29  134.869995  136.690002 -1.820007 -1.331485 -1.820007 -1.331485
# 2020-12-30  133.720001  134.869995 -1.149994 -0.852668 -1.149994 -0.852668
# 2020-12-31  132.690002  133.720001 -1.029999 -0.770265 -1.029999 -0.770265
#
# [2769 rows x 6 columns]

# %%
# delete the columns...

# %%
del apple['Diff2']
apple
# Out:
#                   AAPL        lag1      Diff  % change  %change2
# Date
# 2010-01-04    7.643214         NaN       NaN       NaN       NaN
# 2010-01-05    7.656429    7.643214  0.013215  0.172893  0.172893
# 2010-01-06    7.534643    7.656429 -0.121786 -1.590632 -1.590632
# 2010-01-07    7.520714    7.534643 -0.013929 -0.184871 -0.184871
# 2010-01-08    7.570714    7.520714  0.050000  0.664833  0.664833
# ...                ...         ...       ...       ...       ...
# 2020-12-24  131.970001  130.960007  1.009995  0.771224  0.771224
# 2020-12-28  136.690002  131.970001  4.720001  3.576571  3.576571
# 2020-12-29  134.869995  136.690002 -1.820007 -1.331485 -1.331485
# 2020-12-30  133.720001  134.869995 -1.149994 -0.852668 -0.852668
# 2020-12-31  132.690002  133.720001 -1.029999 -0.770265 -0.770265
#
# [2769 rows x 5 columns]

# %%
del apple['% change']
apple
# Out:
#                   AAPL        lag1      Diff  %change2
# Date
# 2010-01-04    7.643214         NaN       NaN       NaN
# 2010-01-05    7.656429    7.643214  0.013215  0.172893
# 2010-01-06    7.534643    7.656429 -0.121786 -1.590632
# 2010-01-07    7.520714    7.534643 -0.013929 -0.184871
# 2010-01-08    7.570714    7.520714  0.050000  0.664833
# ...                ...         ...       ...       ...
# 2020-12-24  131.970001  130.960007  1.009995  0.771224
# 2020-12-28  136.690002  131.970001  4.720001  3.576571
# 2020-12-29  134.869995  136.690002 -1.820007 -1.331485
# 2020-12-30  133.720001  134.869995 -1.149994 -0.852668
# 2020-12-31  132.690002  133.720001 -1.029999 -0.770265
#
# [2769 rows x 4 columns]

# %%
# changing the name of the functions...
apple.columns
# Out:
# Index(['AAPL', 'lag1', 'Diff', '%change2'], dtype='object')

# %%
apple.rename(columns={'%change2':'change'}, inplace = True)
apple
# Out:
#                   AAPL        lag1      Diff    change
# Date
# 2010-01-04    7.643214         NaN       NaN       NaN
# 2010-01-05    7.656429    7.643214  0.013215  0.172893
# 2010-01-06    7.534643    7.656429 -0.121786 -1.590632
# 2010-01-07    7.520714    7.534643 -0.013929 -0.184871
# 2010-01-08    7.570714    7.520714  0.050000  0.664833
# ...                ...         ...       ...       ...
# 2020-12-24  131.970001  130.960007  1.009995  0.771224
# 2020-12-28  136.690002  131.970001  4.720001  3.576571
# 2020-12-29  134.869995  136.690002 -1.820007 -1.331485
# 2020-12-30  133.720001  134.869995 -1.149994 -0.852668
# 2020-12-31  132.690002  133.720001 -1.029999 -0.770265
#
# [2769 rows x 4 columns]

# %%
apple
# Out:
#                   AAPL        lag1      Diff    change
# Date
# 2010-01-04    7.643214         NaN       NaN       NaN
# 2010-01-05    7.656429    7.643214  0.013215  0.172893
# 2010-01-06    7.534643    7.656429 -0.121786 -1.590632
# 2010-01-07    7.520714    7.534643 -0.013929 -0.184871
# 2010-01-08    7.570714    7.520714  0.050000  0.664833
# ...                ...         ...       ...       ...
# 2020-12-24  131.970001  130.960007  1.009995  0.771224
# 2020-12-28  136.690002  131.970001  4.720001  3.576571
# 2020-12-29  134.869995  136.690002 -1.820007 -1.331485
# 2020-12-30  133.720001  134.869995 -1.149994 -0.852668
# 2020-12-31  132.690002  133.720001 -1.029999 -0.770265
#
# [2769 rows x 4 columns]

# %%
apple.AAPL.resample('M').last()
# Out:
# Date
# 2010-01-31      6.859286
# 2010-02-28      7.307857
# 2010-03-31      8.392857
# 2010-04-30      9.324643
# 2010-05-31      9.174286
#                  ...
# 2020-08-31    129.039993
# 2020-09-30    115.809998
# 2020-10-31    108.860001
# 2020-11-30    119.050003
# 2020-12-31    132.690002
# Freq: M, Name: AAPL, Length: 132, dtype: float64

# %%
# resample using the last business day 'BM'

# %%
apple.AAPL.resample("BM").last().pct_change(periods=1).mul(100)
# Out:
# Date
# 2010-01-29          NaN
# 2010-02-26     6.539620
# 2010-03-31    14.847028
# 2010-04-30    11.102138
# 2010-05-31    -1.612472
#                 ...
# 2020-08-31    21.437974
# 2020-09-30   -10.252632
# 2020-10-30    -6.001206
# 2020-11-30     9.360649
# 2020-12-31    11.457370
# Freq: BM, Name: AAPL, Length: 132, dtype: float64

# %%
# calculating the mid-return and std...

# %%
del apple['change']
apple
# Out:
#                   AAPL        lag1      Diff
# Date
# 2010-01-04    7.643214         NaN       NaN
# 2010-01-05    7.656429    7.643214  0.013215
# 2010-01-06    7.534643    7.656429 -0.121786
# 2010-01-07    7.520714    7.534643 -0.013929
# 2010-01-08    7.570714    7.520714  0.050000
# ...                ...         ...       ...
# 2020-12-24  131.970001  130.960007  1.009995
# 2020-12-28  136.690002  131.970001  4.720001
# 2020-12-29  134.869995  136.690002 -1.820007
# 2020-12-30  133.720001  134.869995 -1.149994
# 2020-12-31  132.690002  133.720001 -1.029999
#
# [2769 rows x 3 columns]

# %%
ret = apple.pct_change().dropna()

# %%
ret
# Out:
#                 AAPL      lag1       Diff
# Date
# 2010-01-06 -0.015906  0.001729 -10.216000
# 2010-01-07 -0.001849 -0.015906  -0.885624
# 2010-01-08  0.006648 -0.001849  -4.589552
# 2010-01-11 -0.008821  0.006648  -2.335692
# 2010-01-12 -0.011375 -0.008821   0.278106
# ...              ...       ...        ...
# 2020-12-24  0.007712 -0.006976  -2.097822
# 2020-12-28  0.035766  0.007712   3.673294
# 2020-12-29 -0.013315  0.035766  -1.385595
# 2020-12-30 -0.008527 -0.013315  -0.368138
# 2020-12-31 -0.007703 -0.008527  -0.104344
#
# [2767 rows x 3 columns]

# %%
ret.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2767 entries, 2010-01-06 to 2020-12-31
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AAPL    2767 non-null   float64
#  1   lag1    2767 non-null   float64
#  2   Diff    2767 non-null   float64
# dtypes: float64(3)
# memory usage: 86.5 KB

# %%
# ret.plot(kind='hist',figsize=(12,8), bins = 100)
# plt.show()

# %%
# calculating the mid-return...

# %%
daily_mean_ret = ret.mean()
daily_mean_ret
# Out:
# AAPL    0.001191
# lag1    0.001194
# Diff         NaN
# dtype: float64

# %%
var_daily = ret.var()
var_daily
# Out:
# AAPL    0.000318
# lag1    0.000318
# Diff         NaN
# dtype: float64

# %%
std_daily = np.sqrt(var_daily)
std_daily
# Out:
# AAPL    0.017846
# lag1    0.017845
# Diff         NaN
# dtype: float64

# %%
ret.std() # alternative way
# Out:
# AAPL    0.017846
# lag1    0.017845
# Diff         NaN
# dtype: float64

# %%
 # annual_mean_return

annual_mean_ret = daily_mean_ret * 252
annual_mean_ret
# Out:
# AAPL    0.300085
# lag1    0.300944
# Diff         NaN
# dtype: float64

# %%
annual_var_return = var_daily * 252
annual_var_return
# Out:
# AAPL    0.080255
# lag1    0.080248
# Diff         NaN
# dtype: float64

# %%
annual_std_return = np.sqrt(annual_var_return)
annual_std_return
# Out:
# AAPL    0.283293
# lag1    0.283281
# Diff         NaN
# dtype: float64

# %%
ret.std() * np.sqrt(252) # alternative way
# Out:
# AAPL    0.283293
# lag1    0.283281
# Diff         NaN
# dtype: float64

# %%
# ticker

# %%
ticker = ['SPY', 'AAPL', 'KO','IBM','DIS','MSFT']

# %%
stocks = yf.download(ticker, start = '2010-01-01')
# Out:
# [*********************100%%**********************]  6 of 6 completed

# %%
close = stocks.loc[:,'Close'].copy()

# %%
norm_close = close.div(close.iloc[0]).mul(100)
norm_close
# Out:
#                    AAPL         DIS         IBM          KO         MSFT  \
# Date
# 2010-01-04   100.000000  100.000000  100.000000  100.000000   100.000000
# 2010-01-05   100.172893   99.750546   98.792000   98.790318   100.032305
# 2010-01-06    98.579511   99.220455   98.150247   98.755261    99.418416
# 2010-01-07    98.397266   99.251638   97.810499   98.509814    98.384491
# 2010-01-08    99.051443   99.407544   98.792000   96.686537    99.063002
# ...                 ...         ...         ...         ...          ...
# 2024-04-01  2224.587638  378.952292  149.914825  212.762971  1371.793205
# 2024-04-02  2209.018240  382.974745  149.164582  210.904630  1361.680104
# 2024-04-03  2219.615843  371.000949  150.759832  209.782612  1358.481428
# 2024-04-04  2208.756713  365.107569  148.422232  207.924258  1350.177688
# 2024-04-05  2218.700102  369.130023  149.369908  208.660580  1374.862612
#
#                    SPY
# Date
# 2010-01-04  100.000000
# 2010-01-05  100.264710
# ...

# %%
norm_close.plot(figsize = (12,5), fontsize = 12)
plt.legend(fontsize = 12)
plt.show()

# %%
ret = close.pct_change().dropna()
ret.head()
# Out:
#                 AAPL       DIS       IBM        KO      MSFT       SPY
# Date
# 2010-01-05  0.001729 -0.002495 -0.012080 -0.012097  0.000323  0.002647
# 2010-01-06 -0.015906 -0.005314 -0.006496 -0.000355 -0.006137  0.000704
# 2010-01-07 -0.001849  0.000314 -0.003462 -0.002485 -0.010400  0.004221
# 2010-01-08  0.006648  0.001571  0.010035 -0.018509  0.006897  0.003328
# 2010-01-11 -0.008821 -0.016311 -0.010470  0.020308 -0.012720  0.001397

# %%
ret.describe().T
# Out:
#        count      mean       std       min       25%       50%       75%  \
# AAPL  3587.0  0.001021  0.017698 -0.128647 -0.007559  0.000811  0.010357
# DIS   3587.0  0.000500  0.016511 -0.131632 -0.006842  0.000452  0.008263
# IBM   3587.0  0.000211  0.014064 -0.128507 -0.006264  0.000394  0.007002
# KO    3587.0  0.000264  0.010871 -0.096725 -0.004816  0.000475  0.005728
# MSFT  3587.0  0.000863  0.016281 -0.147390 -0.007184  0.000588  0.009222
# SPY   3587.0  0.000484  0.010897 -0.109424 -0.003838  0.000599  0.005783
#
#            max
# AAPL  0.119808
# DIS   0.144123
# IBM   0.113010
# KO    0.064796
# MSFT  0.142169
# SPY   0.090603

# %%
summary = ret.describe().T.loc[:,['mean','std']]

# %%
summary
# Out:
#           mean       std
# AAPL  0.001021  0.017698
# DIS   0.000500  0.016511
# IBM   0.000211  0.014064
# KO    0.000264  0.010871
# MSFT  0.000863  0.016281
# SPY   0.000484  0.010897

# %%
summary['mean'] = summary['mean'] * 252
summary['std'] = summary['std'] * np.sqrt(252)
summary
# Out:
#           mean       std
# AAPL  0.257333  0.280946
# DIS   0.126054  0.262101
# IBM   0.053225  0.223266
# KO    0.066638  0.172571
# MSFT  0.217583  0.258449
# SPY   0.121859  0.172977

# %%
summary.plot.scatter(x='std', y= 'mean',figsize=(12,8),s=50,fontsize=15)
plt.show()

# %%
# annotating
summary.plot.scatter(x='std',y='mean',figsize=(12,10), s=50, fontsize=15)
for i in summary.index:
    plt.annotate(i, xy=(summary.loc[i,'std']+0.002,summary.loc[i,'mean']+0.002),size=15)
    
    
plt.xlabel("Annual risk (std)", fontsize= 15)
plt.ylabel('Annual return', fontsize=15)
plt.title('Risk/Return', fontsize=25)
plt.show()

# %% [markdown]
# #from the graph, as you take more risk, you get more reward,,, IBM - A bad investment
# #however, on SPY - small risk, we have more returns(good investment)
# #If i want more returns, i go with Apple, however that comes with much risk

# %% [markdown]
# ## Correlation and Covariance

# %%
ret
# Out:
#                 AAPL       DIS       IBM        KO      MSFT       SPY
# Date
# 2010-01-05  0.001729 -0.002495 -0.012080 -0.012097  0.000323  0.002647
# 2010-01-06 -0.015906 -0.005314 -0.006496 -0.000355 -0.006137  0.000704
# 2010-01-07 -0.001849  0.000314 -0.003462 -0.002485 -0.010400  0.004221
# 2010-01-08  0.006648  0.001571  0.010035 -0.018509  0.006897  0.003328
# 2010-01-11 -0.008821 -0.016311 -0.010470  0.020308 -0.012720  0.001397
# ...              ...       ...       ...       ...       ...       ...
# 2024-04-01 -0.008456 -0.006783 -0.005917 -0.008173  0.009151 -0.001740
# 2024-04-02 -0.006999  0.010615 -0.005004 -0.008734 -0.007372 -0.006358
# 2024-04-03  0.004797 -0.031265  0.010695 -0.005320 -0.002349  0.001099
# 2024-04-04 -0.004892 -0.015885 -0.015505 -0.008858 -0.006113 -0.012206
# 2024-04-05  0.004502  0.011017  0.006385  0.003541  0.018283  0.010447
#
# [3587 rows x 6 columns]

# %%
ret.cov()
# Out:
#           AAPL       DIS       IBM        KO      MSFT       SPY
# AAPL  0.000313  0.000120  0.000100  0.000066  0.000170  0.000133
# DIS   0.000120  0.000273  0.000100  0.000077  0.000124  0.000122
# IBM   0.000100  0.000100  0.000198  0.000072  0.000106  0.000099
# KO    0.000066  0.000077  0.000072  0.000118  0.000072  0.000072
# MSFT  0.000170  0.000124  0.000106  0.000072  0.000265  0.000134
# SPY   0.000133  0.000122  0.000099  0.000072  0.000134  0.000119

# %%
ret.corr()
# Out:
#           AAPL       DIS       IBM        KO      MSFT       SPY
# AAPL  1.000000  0.410283  0.401852  0.344509  0.589621  0.688273
# DIS   0.410283  1.000000  0.428692  0.431250  0.462756  0.680328
# IBM   0.401852  0.428692  1.000000  0.471068  0.462297  0.644793
# KO    0.344509  0.431250  0.471068  1.000000  0.407589  0.609759
# MSFT  0.589621  0.462756  0.462297  0.407589  1.000000  0.753338
# SPY   0.688273  0.680328  0.644793  0.609759  0.753338  1.000000

# %% [markdown]
# #### graphic representation - Heatmap

# %%
import seaborn as sns

# %%
plt.figure(figsize=(12,8))
sns.set(font_scale=1.4)
sns.heatmap(ret.corr(), cmap='Reds',annot=True, annot_kws={'size':'15'},vmax=0.6)
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.set(font_scale=1.4)
sns.heatmap(ret.cov(), cmap='Reds',annot=True, annot_kws={'size':'15'},vmax=0.6)
plt.show()

# %% [markdown]
# ## Simple returns and log returns

# %%
df = pd.DataFrame(index=[2016,2017,2018], data=[100,50,95],columns=['Price'])
df
# Out:
#       Price
# 2016    100
# 2017     50
# 2018     95

# %%
# calculate the simple returns
simple_returns = df.pct_change().dropna()

# %%
simple_returns
# Out:
#       Price
# 2017   -0.5
# 2018    0.9

# %%
simple_returns.mean()
# Out:
# Price    0.2
# dtype: float64

# %%
# on testing it, we get some false results!
100*1.2*1.2 # the result is 144 but in reality, it was 95..
# Out:
# 144.0

# %%
# mean returns are misleading as crazy...

# %%
log_returns = np.log(df/df.shift(1)).dropna()
log_returns
# Out:
#          Price
# 2017 -0.693147
# 2018  0.641854

# %%
log_returns.mean()
# Out:
# Price   -0.025647
# dtype: float64

# %%
100*np.exp(log_returns.mean() * 2) # here we get the end result!
# Out:
# Price    95.0
# dtype: float64

# %%
## Therefore log returns is more accurate as compared to simple returnsabs

# %%
spy = yf.download("SPY")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
spy
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 1993-01-29   43.968750   43.968750   43.750000   43.937500   24.763741
# 1993-02-01   43.968750   44.250000   43.968750   44.250000   24.939871
# 1993-02-02   44.218750   44.375000   44.125000   44.343750   24.992699
# 1993-02-03   44.406250   44.843750   44.375000   44.812500   25.256887
# 1993-02-04   44.968750   45.093750   44.468750   45.000000   25.362574
# ...                ...         ...         ...         ...         ...
# 2024-04-01  523.830017  524.380005  520.969971  522.159973  522.159973
# 2024-04-02  518.239990  518.979980  516.479980  518.840027  518.840027
# 2024-04-03  517.719971  520.950012  517.669983  519.409973  519.409973
# 2024-04-04  523.520020  523.869995  512.760010  513.070007  513.070007
# 2024-04-05  514.460022  520.440002  514.010010  518.429993  518.429993
#
#               Volume
# Date
# 1993-01-29   1003200
# 1993-02-01    480500
# 1993-02-02    201300
# ...

# %%
spy = spy.Close

# %%
spy = spy.to_frame()

# %%
spy
# Out:
#                  Close
# Date
# 1993-01-29   43.937500
# 1993-02-01   44.250000
# 1993-02-02   44.343750
# 1993-02-03   44.812500
# 1993-02-04   45.000000
# ...                ...
# 2024-04-01  522.159973
# 2024-04-02  518.840027
# 2024-04-03  519.409973
# 2024-04-04  513.070007
# 2024-04-05  518.429993
#
# [7852 rows x 1 columns]

# %%
spy.plot(figsize=(12,8), fontsize=15)
plt.legend(loc='upper left', fontsize=15)
plt.show()

# %%
spy_roll = spy.rolling(window=10)
spy_roll = spy_roll.mean()
spy_roll
# Out:
#                  Close
# Date
# 1993-01-29         NaN
# 1993-02-01         NaN
# 1993-02-02         NaN
# 1993-02-03         NaN
# 1993-02-04         NaN
# ...                ...
# 2024-04-01  519.944000
# 2024-04-02  520.542004
# 2024-04-03  520.912000
# 2024-04-04  520.171002
# 2024-04-05  519.794000
#
# [7852 rows x 1 columns]

# %%
spy_roll.head(15)
# Out:
#                 Close
# Date
# 1993-01-29        NaN
# 1993-02-01        NaN
# 1993-02-02        NaN
# 1993-02-03        NaN
# 1993-02-04        NaN
# 1993-02-05        NaN
# 1993-02-08        NaN
# 1993-02-09        NaN
# 1993-02-10        NaN
# 1993-02-11  44.659375
# 1993-02-12  44.725000
# 1993-02-16  44.646875
# 1993-02-17  44.556250
# 1993-02-18  44.415625
# 1993-02-19  44.271875

# %%
spy.rolling(window=10, min_periods=5).max()
# Out:
#                  Close
# Date
# 1993-01-29         NaN
# 1993-02-01         NaN
# 1993-02-02         NaN
# 1993-02-03         NaN
# 1993-02-04   45.000000
# ...                ...
# 2024-04-01  523.169983
# 2024-04-02  523.169983
# 2024-04-03  523.169983
# 2024-04-04  523.169983
# 2024-04-05  523.169983
#
# [7852 rows x 1 columns]

# %% [markdown]
# ## Calculating the 50 day's moving average

# %%
spy
# Out:
#                  Close
# Date
# 1993-01-29   43.937500
# 1993-02-01   44.250000
# 1993-02-02   44.343750
# 1993-02-03   44.812500
# 1993-02-04   45.000000
# ...                ...
# 2024-04-01  522.159973
# 2024-04-02  518.840027
# 2024-04-03  519.409973
# 2024-04-04  513.070007
# 2024-04-05  518.429993
#
# [7852 rows x 1 columns]

# %%
spy['SMA50'] = spy.rolling(window=50,min_periods=50).mean()
spy
# Out:
#                  Close       SMA50
# Date
# 1993-01-29   43.937500         NaN
# 1993-02-01   44.250000         NaN
# 1993-02-02   44.343750         NaN
# 1993-02-03   44.812500         NaN
# 1993-02-04   45.000000         NaN
# ...                ...         ...
# 2024-04-01  522.159973  504.258000
# 2024-04-02  518.840027  504.986201
# 2024-04-03  519.409973  505.705400
# 2024-04-04  513.070007  506.269601
# 2024-04-05  518.429993  506.930400
#
# [7852 rows x 2 columns]

# %%
spy.plot(figsize=(12,8), fontsize=15)
plt.legend(loc='upper left', fontsize=15)
plt.show()

# %%
spy['SMA200'] = spy.Close.rolling(window=200,min_periods=200).mean()
spy
# Out:
#                  Close       SMA50      SMA200
# Date
# 1993-01-29   43.937500         NaN         NaN
# 1993-02-01   44.250000         NaN         NaN
# 1993-02-02   44.343750         NaN         NaN
# 1993-02-03   44.812500         NaN         NaN
# 1993-02-04   45.000000         NaN         NaN
# ...                ...         ...         ...
# 2024-04-01  522.159973  504.258000  461.112401
# 2024-04-02  518.840027  504.986201  461.520701
# 2024-04-03  519.409973  505.705400  461.904751
# 2024-04-04  513.070007  506.269601  462.272801
# 2024-04-05  518.429993  506.930400  462.679051
#
# [7852 rows x 3 columns]

# %%
spy.plot(figsize=(12,8), fontsize=15)
plt.legend(loc='upper left', fontsize=15)
plt.show()

# %%
spy['Day'] = spy.index.day_name()
spy
# Out:
#                  Close       SMA50      SMA200        Day
# Date
# 1993-01-29   43.937500         NaN         NaN     Friday
# 1993-02-01   44.250000         NaN         NaN     Monday
# 1993-02-02   44.343750         NaN         NaN    Tuesday
# 1993-02-03   44.812500         NaN         NaN  Wednesday
# 1993-02-04   45.000000         NaN         NaN   Thursday
# ...                ...         ...         ...        ...
# 2024-04-01  522.159973  504.258000  461.112401     Monday
# 2024-04-02  518.840027  504.986201  461.520701    Tuesday
# 2024-04-03  519.409973  505.705400  461.904751  Wednesday
# 2024-04-04  513.070007  506.269601  462.272801   Thursday
# 2024-04-05  518.429993  506.930400  462.679051     Friday
#
# [7852 rows x 4 columns]

# %%
spy['Quarter'] = spy.index.quarter
spy
# Out:
#                  Close       SMA50      SMA200        Day  Quarter
# Date
# 1993-01-29   43.937500         NaN         NaN     Friday        1
# 1993-02-01   44.250000         NaN         NaN     Monday        1
# 1993-02-02   44.343750         NaN         NaN    Tuesday        1
# 1993-02-03   44.812500         NaN         NaN  Wednesday        1
# 1993-02-04   45.000000         NaN         NaN   Thursday        1
# ...                ...         ...         ...        ...      ...
# 2024-04-01  522.159973  504.258000  461.112401     Monday        2
# 2024-04-02  518.840027  504.986201  461.520701    Tuesday        2
# 2024-04-03  519.409973  505.705400  461.904751  Wednesday        2
# 2024-04-04  513.070007  506.269601  462.272801   Thursday        2
# 2024-04-05  518.429993  506.930400  462.679051     Friday        2
#
# [7852 rows x 5 columns]

# %%
SPY = yf.download('SPY')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
spy = SPY.Close

# %%
spy = spy.to_frame()

# %%
spy
# Out:
#                  Close
# Date
# 1993-01-29   43.937500
# 1993-02-01   44.250000
# 1993-02-02   44.343750
# 1993-02-03   44.812500
# 1993-02-04   45.000000
# ...                ...
# 2024-04-01  522.159973
# 2024-04-02  518.840027
# 2024-04-03  519.409973
# 2024-04-04  513.070007
# 2024-04-05  518.429993
#
# [7852 rows x 1 columns]

# %%
all_days = pd.date_range(start="2010-12-31", end="2020-01-01", freq="D")
all_days
# Out:
# DatetimeIndex(['2010-12-31', '2011-01-01', '2011-01-02', '2011-01-03',
#                '2011-01-04', '2011-01-05', '2011-01-06', '2011-01-07',
#                '2011-01-08', '2011-01-09',
#                ...
#                '2019-12-23', '2019-12-24', '2019-12-25', '2019-12-26',
#                '2019-12-27', '2019-12-28', '2019-12-29', '2019-12-30',
#                '2019-12-31', '2020-01-01'],
#               dtype='datetime64[ns]', length=3289, freq='D')

# %%
spy
# Out:
#                  Close
# Date
# 1993-01-29   43.937500
# 1993-02-01   44.250000
# 1993-02-02   44.343750
# 1993-02-03   44.812500
# 1993-02-04   45.000000
# ...                ...
# 2024-04-01  522.159973
# 2024-04-02  518.840027
# 2024-04-03  519.409973
# 2024-04-04  513.070007
# 2024-04-05  518.429993
#
# [7852 rows x 1 columns]

# %%
spy = spy.reindex(all_days)
spy
# Out:
#                  Close
# 2010-12-31  125.750000
# 2011-01-01         NaN
# 2011-01-02         NaN
# 2011-01-03  127.050003
# 2011-01-04  126.980003
# ...                ...
# 2019-12-28         NaN
# 2019-12-29         NaN
# 2019-12-30  321.079987
# 2019-12-31  321.859985
# 2020-01-01         NaN
#
# [3289 rows x 1 columns]

# %%
spy.fillna(method='ffill')
# Out:
#                  Close
# 2010-12-31  125.750000
# 2011-01-01  125.750000
# 2011-01-02  125.750000
# 2011-01-03  127.050003
# 2011-01-04  126.980003
# ...                ...
# 2019-12-28  322.859985
# 2019-12-29  322.859985
# 2019-12-30  321.079987
# 2019-12-31  321.859985
# 2020-01-01  321.859985
#
# [3289 rows x 1 columns]

# %%
spy.fillna(method='bfill')
# Out:
#                  Close
# 2010-12-31  125.750000
# 2011-01-01  127.050003
# 2011-01-02  127.050003
# 2011-01-03  127.050003
# 2011-01-04  126.980003
# ...                ...
# 2019-12-28  321.079987
# 2019-12-29  321.079987
# 2019-12-30  321.079987
# 2019-12-31  321.859985
# 2020-01-01         NaN
#
# [3289 rows x 1 columns]

# %%
SPY = yf.download('SPY', interval='1wk')
SPY
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 1993-01-25   43.968750   43.968750   43.750000   43.937500   24.763739
# 1993-02-01   43.968750   45.093750   43.968750   44.968750   25.344950
# 1993-02-08   44.968750   45.125000   44.531250   44.593750   25.133615
# 1993-02-15   44.468750   44.468750   42.812500   43.562500   24.552378
# 1993-02-22   43.687500   44.437500   43.468750   44.406250   25.027931
# ...                ...         ...         ...         ...         ...
# 2024-03-04  512.030029  518.219971  504.910004  511.720001  510.134979
# 2024-03-11  510.480011  517.380005  508.119995  509.829987  508.250824
# 2024-03-18  514.000000  524.109985  511.119995  521.210022  521.210022
# 2024-03-25  519.799988  524.609985  518.400024  523.070007  523.070007
# 2024-04-01  523.830017  524.380005  512.760010  518.429993  518.429993
#
#                Volume
# Date
# ...

# %% [markdown]
# ## Finding the maximum drawdowns/cummulative returns

# %%
# download the apple data

# %%
apple = yf.download('AAPL')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
apple = apple.Close.to_frame()
apple
# Out:
#                  Close
# Date
# 1980-12-12    0.128348
# 1980-12-15    0.121652
# 1980-12-16    0.112723
# 1980-12-17    0.115513
# 1980-12-18    0.118862
# ...                ...
# 2024-04-01  170.029999
# 2024-04-02  168.839996
# 2024-04-03  169.649994
# 2024-04-04  168.820007
# 2024-04-05  169.580002
#
# [10919 rows x 1 columns]

# %%
apple['d_returns'] = np.log(apple.div(apple.shift(1)))
apple
# Out:
#                  Close  d_returns
# Date
# 1980-12-12    0.128348        NaN
# 1980-12-15    0.121652  -0.053581
# 1980-12-16    0.112723  -0.076231
# 1980-12-17    0.115513   0.024450
# 1980-12-18    0.118862   0.028580
# ...                ...        ...
# 2024-04-01  170.029999  -0.008492
# 2024-04-02  168.839996  -0.007023
# 2024-04-03  169.649994   0.004786
# 2024-04-04  168.820007  -0.004904
# 2024-04-05  169.580002   0.004492
#
# [10919 rows x 2 columns]

# %%
apple.dropna(inplace=True)
apple
# Out:
#                  Close  d_returns
# Date
# 1980-12-15    0.121652  -0.053581
# 1980-12-16    0.112723  -0.076231
# 1980-12-17    0.115513   0.024450
# 1980-12-18    0.118862   0.028580
# 1980-12-19    0.126116   0.059239
# ...                ...        ...
# 2024-04-01  170.029999  -0.008492
# 2024-04-02  168.839996  -0.007023
# 2024-04-03  169.649994   0.004786
# 2024-04-04  168.820007  -0.004904
# 2024-04-05  169.580002   0.004492
#
# [10918 rows x 2 columns]

# %%
apple.d_returns.sum()
# Out:
# 7.186334812193207

# %%
np.exp(apple.d_returns.sum()) # one dollar invested at the start would now be worth 1321
# Out:
# 1321.2516846063982

# %%
1000 * np.exp(apple.d_returns.sum())## 1000 -> 1,321,251 dollars
# Out:
# 1321251.6846063982

# %%
apple['cumm_returns'] = apple.d_returns.cumsum().apply(np.exp)

# %%
apple
# Out:
#                  Close  d_returns  cumm_returns
# Date
# 1980-12-15    0.121652  -0.053581      0.947829
# 1980-12-16    0.112723  -0.076231      0.878261
# 1980-12-17    0.115513   0.024450      0.899998
# 1980-12-18    0.118862   0.028580      0.926092
# 1980-12-19    0.126116   0.059239      0.982610
# ...                ...        ...           ...
# 2024-04-01  170.029999  -0.008492   1324.757754
# 2024-04-02  168.839996  -0.007023   1315.486067
# 2024-04-03  169.649994   0.004786   1321.797015
# 2024-04-04  168.820007  -0.004904   1315.330326
# 2024-04-05  169.580002   0.004492   1321.251685
#
# [10918 rows x 3 columns]

# %%
apple.cumm_returns.plot(figsize=(12,8), title='APPLE Buy and Hold', fontsize=12)
plt.show()

# %%
apple.d_returns.mean()*252
# Out:
# 0.16586887458075547

# %%
apple.d_returns.std()*np.sqrt(252)
# Out:
# 0.4504876093280397

# %% [markdown]
# ### How to calculate the drawdowns!!

# %%
## What is the maximum drawdown?

# %%
apple['cummax'] = apple.cumm_returns.cummax()
apple
# Out:
#                  Close  d_returns  cumm_returns       cummax
# Date
# 1980-12-15    0.121652  -0.053581      0.947829     0.947829
# 1980-12-16    0.112723  -0.076231      0.878261     0.947829
# 1980-12-17    0.115513   0.024450      0.899998     0.947829
# 1980-12-18    0.118862   0.028580      0.926092     0.947829
# 1980-12-19    0.126116   0.059239      0.982610     0.982610
# ...                ...        ...           ...          ...
# 2024-04-01  170.029999  -0.008492   1324.757754  1543.537972
# 2024-04-02  168.839996  -0.007023   1315.486067  1543.537972
# 2024-04-03  169.649994   0.004786   1321.797015  1543.537972
# 2024-04-04  168.820007  -0.004904   1315.330326  1543.537972
# 2024-04-05  169.580002   0.004492   1321.251685  1543.537972
#
# [10918 rows x 4 columns]

# %%
apple[['cumm_returns','cummax']].plot(figsize=(12,8), title='APPLE Buy and Hold', fontsize=12)
plt.show()

# %%
apple['drawdown'] = apple["cummax"] - apple["cumm_returns"]
apple
# Out:
#                  Close  d_returns  cumm_returns       cummax    drawdown
# Date
# 1980-12-15    0.121652  -0.053581      0.947829     0.947829    0.000000
# 1980-12-16    0.112723  -0.076231      0.878261     0.947829    0.069569
# 1980-12-17    0.115513   0.024450      0.899998     0.947829    0.047831
# 1980-12-18    0.118862   0.028580      0.926092     0.947829    0.021738
# 1980-12-19    0.126116   0.059239      0.982610     0.982610    0.000000
# ...                ...        ...           ...          ...         ...
# 2024-04-01  170.029999  -0.008492   1324.757754  1543.537972  218.780218
# 2024-04-02  168.839996  -0.007023   1315.486067  1543.537972  228.051905
# 2024-04-03  169.649994   0.004786   1321.797015  1543.537972  221.740957
# 2024-04-04  168.820007  -0.004904   1315.330326  1543.537972  228.207646
# 2024-04-05  169.580002   0.004492   1321.251685  1543.537972  222.286287
#
# [10918 rows x 5 columns]

# %%
apple.drawdown.max() # the maximum drawdown..
# Out:
# 444.02718404402026

# %%
apple.drawdown.idxmax() # to see the date of this drawdown
# Out:
# Timestamp('2023-01-05 00:00:00')

# %%
apple.loc[(apple.index=="2023-01-05")]
# Out:
#                  Close  d_returns  cumm_returns       cummax    drawdown
# Date
# 2023-01-05  125.019997  -0.010661    974.070524  1418.097708  444.027184

# %%
apple.loc[(apple.index<="2023-01-05")]
# Out:
#                  Close  d_returns  cumm_returns       cummax    drawdown
# Date
# 1980-12-15    0.121652  -0.053581      0.947829     0.947829    0.000000
# 1980-12-16    0.112723  -0.076231      0.878261     0.947829    0.069569
# 1980-12-17    0.115513   0.024450      0.899998     0.947829    0.047831
# 1980-12-18    0.118862   0.028580      0.926092     0.947829    0.021738
# 1980-12-19    0.126116   0.059239      0.982610     0.982610    0.000000
# ...                ...        ...           ...          ...         ...
# 2022-12-29  129.610001   0.027931   1009.832703  1418.097708  408.265004
# 2022-12-30  129.929993   0.002466   1012.325863  1418.097708  405.771845
# 2023-01-03  125.070000  -0.038122    974.460113  1418.097708  443.637594
# 2023-01-04  126.360001   0.010261    984.510920  1418.097708  433.586787
# 2023-01-05  125.019997  -0.010661    974.070524  1418.097708  444.027184
#
# [10605 rows x 5 columns]

# %%
apple['drawdown%'] = (apple["cummax"] - apple["cumm_returns"])/apple["cummax"]
apple
# Out:
#                  Close  d_returns  cumm_returns       cummax    drawdown  \
# Date
# 1980-12-15    0.121652  -0.053581      0.947829     0.947829    0.000000
# 1980-12-16    0.112723  -0.076231      0.878261     0.947829    0.069569
# 1980-12-17    0.115513   0.024450      0.899998     0.947829    0.047831
# 1980-12-18    0.118862   0.028580      0.926092     0.947829    0.021738
# 1980-12-19    0.126116   0.059239      0.982610     0.982610    0.000000
# ...                ...        ...           ...          ...         ...
# 2024-04-01  170.029999  -0.008492   1324.757754  1543.537972  218.780218
# 2024-04-02  168.839996  -0.007023   1315.486067  1543.537972  228.051905
# 2024-04-03  169.649994   0.004786   1321.797015  1543.537972  221.740957
# 2024-04-04  168.820007  -0.004904   1315.330326  1543.537972  228.207646
# 2024-04-05  169.580002   0.004492   1321.251685  1543.537972  222.286287
#
#             drawdown%
# Date
# 1980-12-15   0.000000
# 1980-12-16   0.073398
# ...

# %%
apple["drawdown%"].max()
# Out:
# 0.82216567924191

# %%
apple["drawdown%"].idxmax()
# Out:
# Timestamp('1997-12-23 00:00:00')

# %%
apple.loc[(apple.index <= "1997-12-23")]
# Out:
#                Close  d_returns  cumm_returns    cummax  drawdown  drawdown%
# Date
# 1980-12-15  0.121652  -0.053581      0.947829  0.947829  0.000000   0.000000
# 1980-12-16  0.112723  -0.076231      0.878261  0.947829  0.069569   0.073398
# 1980-12-17  0.115513   0.024450      0.899998  0.947829  0.047831   0.050464
# 1980-12-18  0.118862   0.028580      0.926092  0.947829  0.021738   0.022934
# 1980-12-19  0.126116   0.059239      0.982610  0.982610  0.000000   0.000000
# ...              ...        ...           ...       ...       ...        ...
# 1997-12-17  0.124442  -0.026549      0.969567  5.060882  4.091315   0.808419
# 1997-12-18  0.123326  -0.009008      0.960872  5.060882  4.100010   0.810137
# 1997-12-19  0.122210  -0.009090      0.952177  5.060882  4.108705   0.811856
# 1997-12-22  0.118862  -0.027778      0.926092  5.060882  4.134790   0.817010
# 1997-12-23  0.115513  -0.028580      0.899998  5.060882  4.160883   0.822166
#
# [4306 rows x 6 columns]

# %% [markdown]
# ### SMA STRATEGY
# ## moving average crossover

# %%
data = apple.Close.loc[(apple.index >= '1991-01-01')]
data = data.to_frame()

# %%
data
# Out:
#                  Close
# Date
# 1991-01-02    0.388393
# 1991-01-03    0.383929
# 1991-01-04    0.386161
# 1991-01-07    0.386161
# 1991-01-08    0.386161
# ...                ...
# 2024-04-01  170.029999
# 2024-04-02  168.839996
# 2024-04-03  169.649994
# 2024-04-04  168.820007
# 2024-04-05  169.580002
#
# [8378 rows x 1 columns]

# %%
sma_s = 50
sma_l = 100

# %%
data['sma_s'] = data.Close.rolling(sma_s).mean()
data['sma_l'] = data.Close.rolling(sma_l).mean()

# %%
data
# Out:
#                  Close       sma_s     sma_l
# Date
# 1991-01-02    0.388393         NaN       NaN
# 1991-01-03    0.383929         NaN       NaN
# 1991-01-04    0.386161         NaN       NaN
# 1991-01-07    0.386161         NaN       NaN
# 1991-01-08    0.386161         NaN       NaN
# ...                ...         ...       ...
# 2024-04-01  170.029999  180.907199  185.2313
# 2024-04-02  168.839996  180.452799  185.1274
# 2024-04-03  169.649994  179.967999  185.0057
# 2024-04-04  168.820007  179.440800  184.8650
# 2024-04-05  169.580002  178.942400  184.7367
#
# [8378 rows x 3 columns]

# %%
# plotting..

# %%
data.plot(figsize=(12,8),
          title="AAPLE - SMA{} | SMA{}".format(sma_s, sma_l),
         fontsize=12)
plt.show()

# %%
data.loc["2016"].plot(figsize=(12,8),
          title="AAPLE - SMA{} | SMA{}".format(sma_s, sma_l),
         fontsize=12)
plt.show()

# %%
data.dropna(inplace=True)
data
# Out:
#                  Close       sma_s       sma_l
# Date
# 1991-05-23    0.402902    0.534420    0.513326
# 1991-05-24    0.409598    0.530960    0.513538
# 1991-05-28    0.410714    0.527344    0.513806
# 1991-05-29    0.419643    0.523638    0.514141
# 1991-05-30    0.425223    0.519732    0.514531
# ...                ...         ...         ...
# 2024-04-01  170.029999  180.907199  185.231300
# 2024-04-02  168.839996  180.452799  185.127400
# 2024-04-03  169.649994  179.967999  185.005700
# 2024-04-04  168.820007  179.440800  184.865000
# 2024-04-05  169.580002  178.942400  184.736700
#
# [8279 rows x 3 columns]

# %%
data["position"] = np.where(data['sma_s'] > data['sma_l'], 1,-1)# fill 1 else fill with -1
data
# Out:
#                  Close       sma_s       sma_l  position
# Date
# 1991-05-23    0.402902    0.534420    0.513326         1
# 1991-05-24    0.409598    0.530960    0.513538         1
# 1991-05-28    0.410714    0.527344    0.513806         1
# 1991-05-29    0.419643    0.523638    0.514141         1
# 1991-05-30    0.425223    0.519732    0.514531         1
# ...                ...         ...         ...       ...
# 2024-04-01  170.029999  180.907199  185.231300        -1
# 2024-04-02  168.839996  180.452799  185.127400        -1
# 2024-04-03  169.649994  179.967999  185.005700        -1
# 2024-04-04  168.820007  179.440800  184.865000        -1
# 2024-04-05  169.580002  178.942400  184.736700        -1
#
# [8279 rows x 4 columns]

# %%
data.loc[:,['sma_s','sma_l','position']].plot(figsize=(12,8),
          title="AAPLE - SMA{} | SMA{}".format(sma_s, sma_l),
         fontsize=12)
plt.show()

# %%
data.loc["2016",['sma_s','sma_l','position']].plot(figsize=(12,8),
          title="AAPLE - SMA{} | SMA{}".format(sma_s, sma_l),
         fontsize=12, secondary_y = "position")
plt.show()

# %%
data['returns'] = np.log(data.Close.div(data.Close.shift(1)))
data
# Out:
#                  Close       sma_s       sma_l  position   returns
# Date
# 1991-05-23    0.402902    0.534420    0.513326         1       NaN
# 1991-05-24    0.409598    0.530960    0.513538         1  0.016483
# 1991-05-28    0.410714    0.527344    0.513806         1  0.002721
# 1991-05-29    0.419643    0.523638    0.514141         1  0.021507
# 1991-05-30    0.425223    0.519732    0.514531         1  0.013209
# ...                ...         ...         ...       ...       ...
# 2024-04-01  170.029999  180.907199  185.231300        -1 -0.008492
# 2024-04-02  168.839996  180.452799  185.127400        -1 -0.007023
# 2024-04-03  169.649994  179.967999  185.005700        -1  0.004786
# 2024-04-04  168.820007  179.440800  184.865000        -1 -0.004904
# 2024-04-05  169.580002  178.942400  184.736700        -1  0.004492
#
# [8279 rows x 5 columns]

# %%
data['strategy'] = data['returns'] * data.position.shift(1)

# %%
data
# Out:
#                  Close       sma_s       sma_l  position   returns  strategy
# Date
# 1991-05-23    0.402902    0.534420    0.513326         1       NaN       NaN
# 1991-05-24    0.409598    0.530960    0.513538         1  0.016483  0.016483
# 1991-05-28    0.410714    0.527344    0.513806         1  0.002721  0.002721
# 1991-05-29    0.419643    0.523638    0.514141         1  0.021507  0.021507
# 1991-05-30    0.425223    0.519732    0.514531         1  0.013209  0.013209
# ...                ...         ...         ...       ...       ...       ...
# 2024-04-01  170.029999  180.907199  185.231300        -1 -0.008492  0.008492
# 2024-04-02  168.839996  180.452799  185.127400        -1 -0.007023  0.007023
# 2024-04-03  169.649994  179.967999  185.005700        -1  0.004786 -0.004786
# 2024-04-04  168.820007  179.440800  184.865000        -1 -0.004904  0.004904
# 2024-04-05  169.580002  178.942400  184.736700        -1  0.004492 -0.004492
#
# [8279 rows x 6 columns]

# %%
data.dropna(inplace=True)

# %%
data[["returns","strategy"]].sum()
# Out:
# returns     6.042387
# strategy    1.846598
# dtype: float64

# %% [markdown]
# ## What will one dollar be according to this strategy?

# %%
data[["returns","strategy"]].sum().apply(np.exp)
# Out:
# returns     420.896394
# strategy      6.338219
# dtype: float64

# %%
data[["returns","strategy"]].std() * np.sqrt(252)
# Out:
# returns     0.433586
# strategy    0.433727
# dtype: float64

# %%
data.Close.plot(figsize=(12,8))
plt.show()

# %% [markdown]
# ## STRATEGY ADJUSTED WITH LONG BIAS ONLY...
# This is due to the fact that the price of a stock will always be rising and in the long run,the price will eventually rise!

# %%
data['position2'] = np.where(data['sma_s'] > data['sma_l'], 1,0)

# %%
data
# Out:
#                  Close       sma_s       sma_l  position   returns  strategy  \
# Date
# 1991-05-24    0.409598    0.530960    0.513538         1  0.016483  0.016483
# 1991-05-28    0.410714    0.527344    0.513806         1  0.002721  0.002721
# 1991-05-29    0.419643    0.523638    0.514141         1  0.021507  0.021507
# 1991-05-30    0.425223    0.519732    0.514531         1  0.013209  0.013209
# 1991-05-31    0.419643    0.516027    0.514866         1 -0.013209 -0.013209
# ...                ...         ...         ...       ...       ...       ...
# 2024-04-01  170.029999  180.907199  185.231300        -1 -0.008492  0.008492
# 2024-04-02  168.839996  180.452799  185.127400        -1 -0.007023  0.007023
# 2024-04-03  169.649994  179.967999  185.005700        -1  0.004786 -0.004786
# 2024-04-04  168.820007  179.440800  184.865000        -1 -0.004904  0.004904
# 2024-04-05  169.580002  178.942400  184.736700        -1  0.004492 -0.004492
#
#             position2
# Date
# ...

# %%
data['strategy2'] = data['returns'] * data.position2.shift(1)

# %%
data
# Out:
#                  Close       sma_s       sma_l  position   returns  strategy  \
# Date
# 1991-05-24    0.409598    0.530960    0.513538         1  0.016483  0.016483
# 1991-05-28    0.410714    0.527344    0.513806         1  0.002721  0.002721
# 1991-05-29    0.419643    0.523638    0.514141         1  0.021507  0.021507
# 1991-05-30    0.425223    0.519732    0.514531         1  0.013209  0.013209
# 1991-05-31    0.419643    0.516027    0.514866         1 -0.013209 -0.013209
# ...                ...         ...         ...       ...       ...       ...
# 2024-04-01  170.029999  180.907199  185.231300        -1 -0.008492  0.008492
# 2024-04-02  168.839996  180.452799  185.127400        -1 -0.007023  0.007023
# 2024-04-03  169.649994  179.967999  185.005700        -1  0.004786 -0.004786
# 2024-04-04  168.820007  179.440800  184.865000        -1 -0.004904  0.004904
# 2024-04-05  169.580002  178.942400  184.736700        -1  0.004492 -0.004492
#
#             position2  strategy2
# ...

# %%
data.dropna(inplace=True)
data[['returns','strategy2']].sum() # gives better returns than strategy 1
# Out:
# returns      6.025904
# strategy2    3.928009
# dtype: float64

# %%
data[["returns","strategy2"]].std() * np.sqrt(252)
# Out:
# returns      0.433604
# strategy2    0.335217
# dtype: float64

# %% [markdown]
# ## Based on the following data...
# Strategy 2 is better than strategy 1

# %%
# compare the strategy1 and strategy2

# %%
data[['strategy','strategy2']].std()*np.sqrt(252)
# Out:
# strategy     0.433744
# strategy2    0.335217
# dtype: float64

# %% [markdown]
# ### Creating our first function

# %%
def test_strategy(stock, start, end, SMA):
    df = yf.download(stock, start=start, end=end)
    data = df.Close.to_frame()
    data["returns"] = np.log(data.Close.div(data.Close.shift(1)))
    data['SMA_S'] = data.Close.rolling(int(SMA[0])).mean()
    data['SMA_L'] = data.Close.rolling(int(SMA[1])).mean()
    data.dropna(inplace=True)
    
    data['position'] = np.where(data['SMA_S'] > data['SMA_L'], 1,-1)
    data['strategy'] = data['returns'] * data.position.shift(1)
    data.dropna(inplace=True)
    ret = np.exp(data['strategy'].sum())
    std = data['strategy'].std()*np.sqrt(252)
    
    return ret, std

# %%
test_strategy("TSLA","2000-01-01", "2020-01-01",(50,200))
# Out:
# [*********************100%%**********************]  1 of 1 completed
# (1.3908153866370587, 0.49564569049996726)

# %% [markdown]
# ## Creating our first Class

# %%
class SMABacktester():
    def __init__(self,symbol,sma_s, sma_l, start,end):
        self.symbol = symbol
        self.sma_s = sma_s
        self.sma_l = sma_l
        self.start = start
        self.end = end
        self.results = None
        self.get_data()
        
    def get_data(self):
        df = yf.download(self.symbol, start=self.start, end=self.end)
        data = df.Close.to_frame()
        data['returns'] = np.log(data.Close.div(data.Close.shift(1)))
        data['sma_s'] = data.Close.rolling(self.sma_s).mean()
        data['sma_l'] = data.Close.rolling(self.sma_l).mean()
        data.dropna(inplace=True)
        self.data2 = data
        
        return data
    
    
    def test_results(self):
        data = self.data2.copy().dropna()
        data["position"] = np.where(data['sma_s'] > data["sma_l"], 1,-1)
        data['strategy'] = data['returns'] * data.position.shift(1)
        data.dropna(inplace = True)
        data["returnsbh"] = data['returns'].cumsum().apply(np.exp)
        data['returns_strategy'] = data['strategy'].cumsum().apply(np.exp)
        perf = data['returns_strategy'].iloc[-1]
        outperf = perf - data['returnsbh'].iloc[-1]
        self.results = data
        
        ret = np.exp(data['strategy'].sum())
        std = data['strategy'].std() *np.sqrt(252)
        
        # return tuple ret,std
        return round(perf,6), round(outperf,6)
    
    
    def plot_results(self):
        if self.results is None:
            print("Run the test please!")
        else:
            title = "{} | sma_s = {} | sma_l = {}".format(self.symbol, self.sma_s, self.sma_l)
            self.results[["returnsbh", "returns_strategy"]].plot(title=title, figsize=(12,8))
